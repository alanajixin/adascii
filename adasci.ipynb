# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
df=pd.read_csv("C:\\Users\\Asus\\Downloads\\Dataset\\train.csv")

# %%
df.head()
# Out:
#                                                  URL  URLLength  \
# 0                             http://www.playapps.ga         21
# 1                        http://www.bastiontools.net         26
# 2  http://auth-sso-biglobe-sso-mail-63e96e33d9125...        170
# 3                           https://www.santam.co.za         23
# 4                             https://bit.ly/43pohq6         22
#
#                                               Domain  DomainLength  \
# 0                                    www.playapps.ga            15
# 1                               www.bastiontools.net            20
# 2  auth-sso-biglobe-sso-mail-63e96e33d9125.esup.e...            51
# 3                                   www.santam.co.za            16
# 4                                             bit.ly             6
#
#    IsDomainIP  TLD  URLSimilarityIndex  CharContinuationRate  \
# 0           0   ga           77.884615              1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165056 entries, 0 to 165055
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   URL                         165056 non-null  object
#  1   URLLength                   165056 non-null  int64
#  2   Domain                      165056 non-null  object
#  3   DomainLength                165056 non-null  int64
#  4   IsDomainIP                  165056 non-null  int64
#  5   TLD                         165056 non-null  object
#  6   URLSimilarityIndex          165056 non-null  float64
#  7   CharContinuationRate        165056 non-null  float64
#  8   TLDLegitimateProb           165056 non-null  float64
#  9   URLCharProb                 165056 non-null  float64
#  10  TLDLength                   165056 non-null  int64
#  11  NoOfSubDomain               165056 non-null  int64
#  12  HasObfuscation              165056 non-null  int64
# ...

# %%
df.describe()
# Out:
#            URLLength   DomainLength     IsDomainIP  URLSimilarityIndex  \
# count  165056.000000  165056.000000  165056.000000       165056.000000
# mean       34.567771      21.457463       0.002745           78.445896
# std        39.167996       9.127515       0.052316           28.964193
# min        13.000000       4.000000       0.000000            0.197141
# 25%        23.000000      16.000000       0.000000           57.063712
# 50%        27.000000      20.000000       0.000000          100.000000
# 75%        34.000000      24.000000       0.000000          100.000000
# max      6097.000000     110.000000       1.000000          100.000000
#
#        CharContinuationRate  TLDLegitimateProb    URLCharProb      TLDLength  \
# count         165056.000000      165056.000000  165056.000000  165056.000000
# mean               0.845591           0.260464       0.055743       2.763317
# std                0.216659           0.251635       0.010566       0.599727
# ...

# %%
df['TLD'].unique
# Out:
# <bound method Series.unique of 0            ga
# 1           net
# 2            br
# 3            za
# 4            ly
#           ...
# 165051      com
# 165052      com
# 165053      com
# 165054    space
# 165055       jp
# Name: TLD, Length: 165056, dtype: object>

# %%
df['TLD'].value_counts()
# Out:
# com         78803
# org         13136
# net          4978
# app          4520
# uk           4472
#             ...
# 47              1
# post            1
# guitars         1
# 163             1
# com:9595        1
# Name: TLD, Length: 636, dtype: int64

# %%
df[~df['Domain'].str.startswith('www')]
# Out:
#                                                       URL  URLLength  \
# 2       http://auth-sso-biglobe-sso-mail-63e96e33d9125...        170
# 4                                  https://bit.ly/43pohq6         22
# 10              http://project-dapps-intergration.web.app         40
# 14      https://bafybeifq3zkmnaqak2tbb22wqrsckzhiuoc4s...         83
# 18                            https://steanccomnmunity.ru         27
# ...                                                   ...        ...
# 165032                     http://acraqfxyiz.duckdns.org/         30
# 165033             http://bellosuthupdate.weeblysite.com/         38
# 165045                    https://ebikediagnostics.com/jp         30
# 165048                            https://reurl.cc/6l1dqm         22
# 165053         https://domappcheckomeg10.firebaseapp.com/         41
#
#                                                    Domain  DomainLength  \
# ...

# %%
X = pd.get_dummies(df.drop(columns=['URL', 'Domain', 'TLD', 'Title', 'label'], axis=1), drop_first=True)
X
# Out:
#         URLLength  DomainLength  IsDomainIP  URLSimilarityIndex  \
# 0              21            15           0           77.884615
# 1              26            20           0           70.358456
# 2             170            51           0            6.156148
# 3              23            16           0          100.000000
# 4              22             6           0           46.122449
# ...           ...           ...         ...                 ...
# 165051         31            24           0          100.000000
# 165052         26            20           0           79.555556
# 165053         41            33           0           56.398207
# 165054         25            19           0           69.444444
# 165055         31            24           0          100.000000
#
#         CharContinuationRate  TLDLegitimateProb  URLCharProb  TLDLength  \
# 0                   1.000000           0.000226     0.042026          2
# ...

# %%
y=df['label']
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 165051    1
# 165052    0
# 165053    0
# 165054    0
# 165055    1
# Name: label, Length: 165056, dtype: int64

# %% [markdown]
# ## Splitting the Data into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
preds = rfc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# %%
from sklearn.metrics import accuracy_score

# %%
print(confusion_matrix(y_test, preds))
# Out:
# [[14198     0]
#  [    0 18814]]

# %%
print(accuracy_score(y_test, preds))
# Out:
# 1.0

# %%
test=pd.read_csv("C:\\Users\\Asus\\Downloads\\Dataset\\test.csv")

# %%
test
# Out:
#        URLLength  DomainLength  IsDomainIP  URLSimilarityIndex  \
# 0             19            12           0          100.000000
# 1             31            22           0           49.910169
# 2             23            16           0          100.000000
# 3             45            36           0           51.317985
# 4             18            11           0          100.000000
# ...          ...           ...         ...                 ...
# 70734         25            18           0          100.000000
# 70735         21            14           0          100.000000
# 70736         28            21           0          100.000000
# 70737         21            14           0          100.000000
# 70738         21            14           0          100.000000
#
#        CharContinuationRate  TLDLegitimateProb  URLCharProb  TLDLength  \
# 0                  1.000000           0.010183     0.057690          2
# ...

# %%
prediction=rfc.predict(test)

# %%
result = pd.DataFrame(prediction, columns=["label"])

# %%
result
# Out:
#        label
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ...      ...
# 70734      1
# 70735      1
# 70736      1
# 70737      1
# 70738      1
#
# [70739 rows x 1 columns]

# %%
result.to_csv("C:\\Users\\Asus\\Downloads\\Dataset\\result.csv", index=False)
